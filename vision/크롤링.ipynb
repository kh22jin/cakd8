# %% [markdown]
# # 다음

# %%
# 하나만 찾을 때 사용 
soup.find(class_ = 'tit_main fn_tit_u') 
soup.select_one('.tit_main.fn_tit_u')   

# 모두 찾아줄 때 사용
soup.find_all(class_ = 'tit_main fn_tit_u') 
soup.select('.tit_main.fn_tit_u')  # . : class를 뜻함, space바 : .을 넣어서 처리해줌
#soup.select('#tit_main.fn_tit_u')   # : id를 뜻함


#soup.select('#tit_main.fn_tit_u')   # : id를 뜻함

# %% [markdown]
# ## 첫 페이지 불러오기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98'

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

html = requests.get(url, headers = header).text

soup = BeautifulSoup(html, 'lxml')
title = soup.find_all(class_ = 'tit_main fn_tit_u')

for i in title:
    print(i.text, " : ", i.attrs['href'])
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  https://cp.news.search.daum.net/p/124956473
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  http://v.media.daum.net/v/20221027103250575?f=o
# 의외의 복병 우크라이나! 2030부산세계박람회 유치, '우크라이나' 참여로 4파전 돌입  :  https://cp.news.search.daum.net/p/124969970
# '지구안보'의 눈으로 본 우크라이나전쟁  :  http://v.media.daum.net/v/20221027100423316?f=o
# 러시아, 對우크라이나 선전전술 '反나치'서 '反테러'로 바꾼 이유는  :  https://cp.news.search.daum.net/p/124967421
# 전쟁 피해 기숙사서 지내는 우크라이나 어린이들  :  http://v.media.daum.net/v/20221027111607669?f=o
# 굿짹월드, 우크라이나 ‘리드림(REDREAM) 프로젝트’에 3,500만 원 기부  :  https://cp.news.search.daum.net/p/124962113
# 한국 의료기관 도움받은 우크라이나인 감동 손 편지 화제  :  http://v.media.daum.net/v/20221027081605579?f=o
# 우크라이나 전쟁서 미국 역할 반대 여론 '슬금슬금'  :  https://cp.news.search.daum.net/p/124954756
# 승리의 V 그리는 우크라이나 전차병  :  http://v.media.daum.net/v/20221027091904286?f=o

# %% [markdown]
# ## 여러 페이지 불러오기

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98&p='
for i in range(1,3):
    url = url1 + str(i)
    html = requests.get(url, headers = header).text
    
    soup = BeautifulSoup(html, 'lxml')
    title = soup.find_all(class_ = 'tit_main fn_tit_u')
    for j in title:
        print(j.text, " : ", j.attrs['href'])
    print(f'{i}페이지입니다.')
    print("-"*70)
    print('\n')
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  https://cp.news.search.daum.net/p/124956473
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  http://v.media.daum.net/v/20221027103250575?f=o
# 의외의 복병 우크라이나! 2030부산세계박람회 유치, '우크라이나' 참여로 4파전 돌입  :  https://cp.news.search.daum.net/p/124969970
# '지구안보'의 눈으로 본 우크라이나전쟁  :  http://v.media.daum.net/v/20221027100423316?f=o
# 러시아, 對우크라이나 선전전술 '反나치'서 '反테러'로 바꾼 이유는  :  https://cp.news.search.daum.net/p/124967421
# 전쟁 피해 기숙사서 지내는 우크라이나 어린이들  :  http://v.media.daum.net/v/20221027111607669?f=o
# 굿짹월드, 우크라이나 ‘리드림(REDREAM) 프로젝트’에 3,500만 원 기부  :  https://cp.news.search.daum.net/p/124962113
# 한국 의료기관 도움받은 우크라이나인 감동 손 편지 화제  :  http://v.media.daum.net/v/20221027081605579?f=o
# 우크라이나 전쟁서 미국 역할 반대 여론 '슬금슬금'  :  https://cp.news.search.daum.net/p/124954756
# 승리의 V 그리는 우크라이나 전차병  :  http://v.media.daum.net/v/20221027091904286?f=o
# 1페이지입니다.
# ----------------------------------------------------------------------
#
#
# ...

# %% [markdown]
# ## 검색어 바꾸기

# %%
url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
url2 = input("검색어를 입력해 주세요: ")
url3 = '&p='
#'페이지번호'
url = url1 + url2 + url3 + str(1)
url
# Out:
# 검색어를 입력해 주세요: 우크라이나
# 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=우크라이나&p=1'

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
url2 = input("검색어를 입력해 주세요: ")
url3 = '&p='

for i in range(1,3):
    url = url1 + url2 + url3 + str(i)
    html = requests.get(url, headers = header).text
    
    soup = BeautifulSoup(html, 'lxml')
    title = soup.find_all(class_ = 'tit_main fn_tit_u')
    for j in title:
        print(j.text, " : ", j.attrs['href'])
    print(f'{i}페이지입니다.')
    print("-"*100)
    print('\n')
# Out:
# 검색어를 입력해 주세요: 우크라이나
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  https://cp.news.search.daum.net/p/124956473
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  http://v.media.daum.net/v/20221027103250575?f=o
# 의외의 복병 우크라이나! 2030부산세계박람회 유치, '우크라이나' 참여로 4파전 돌입  :  https://cp.news.search.daum.net/p/124969970
# '지구안보'의 눈으로 본 우크라이나전쟁  :  http://v.media.daum.net/v/20221027100423316?f=o
# 러시아, 對우크라이나 선전전술 '反나치'서 '反테러'로 바꾼 이유는  :  https://cp.news.search.daum.net/p/124967421
# 전쟁 피해 기숙사서 지내는 우크라이나 어린이들  :  http://v.media.daum.net/v/20221027111607669?f=o
# 굿짹월드, 우크라이나 ‘리드림(REDREAM) 프로젝트’에 3,500만 원 기부  :  https://cp.news.search.daum.net/p/124962113
# 한국 의료기관 도움받은 우크라이나인 감동 손 편지 화제  :  http://v.media.daum.net/v/20221027081605579?f=o
# 우크라이나 전쟁서 미국 역할 반대 여론 '슬금슬금'  :  https://cp.news.search.daum.net/p/124954756
# 승리의 V 그리는 우크라이나 전차병  :  http://v.media.daum.net/v/20221027091904286?f=o
# 1페이지입니다.
# ----------------------------------------------------------------------------------------------------
#
#
# ...

# %% [markdown]
# ## 사용자 함수로 만들기

# %%
def search(daum):
    import requests
    from bs4 import BeautifulSoup

    header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

    url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
    url3 = '&p='

    for i in range(1,3):
        url = url1 + daum + url3 + str(i)
        html = requests.get(url, headers = header).text

        soup = BeautifulSoup(html, 'lxml')
        title = soup.find_all(class_ = 'tit_main fn_tit_u')
        for j in title:
            print(j.text, " : ", j.attrs['href'])
        print(f'{i}페이지입니다.')
        print("-"*100)
        print('\n')

# %%
search('한국')
# Out:
# 한국 제약 100년..변곡점에 선 韓제약·바이오  :  http://v.media.daum.net/v/20221024060116639?f=o
# “한국에서 미국 주립대 학위 받아요.”  :  http://v.media.daum.net/v/20221027030701102?f=o
# 수출감소에 고물가·어닝쇼크…한국경제 성장 '빨간불'  :  http://v.media.daum.net/v/20221027102915396?f=o
# "젊은 선수들이 부상했다" 한국 찾은 日 국대 사령탑, 젊은 한국 경계  :  http://v.media.daum.net/v/20221027090017525?f=o
# "신참부터 옮겨라?"..한국GM, 인천→창원 인력 재배치 난항  :  http://v.media.daum.net/v/20221025063007786?f=o
# 글로벌펀드 "尹 '1억 달러 약속' 예상 못해…한국 위상 높아졌다"  :  http://v.media.daum.net/v/20221027020044741?f=o
# CEPI 대표 "한국이 혁신 이끌면 팬데믹 피해 다시 안 겪을 것"  :  http://v.media.daum.net/v/20221027102832370?f=o
# 한국이 개량한 젖소 101마리, 처음으로 네팔 간다  :  http://v.media.daum.net/v/20221027113302510?f=o
# [진로 탐구 생활] 세상에 ‘나’를 광고하라! 한국광고박물관  :  http://v.media.daum.net/v/20221027103505690?f=o
# 손흥민이 카타르서 입을 수트, "히어로-K11" 한국축구 단복 공개  :  http://v.media.daum.net/v/20221027115427402?f=o
# 1페이지입니다.
# ----------------------------------------------------------------------------------------------------
#
#
# ...

# %% [markdown]
# # 네이버

# %% [markdown]
# ## 첫 페이지 불러오기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98&nso=so%3Ar%2Cp%3Aall%2Ca%3Aall'

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

html = requests.get(url, headers = header).text

soup = BeautifulSoup(html, 'lxml')
title = soup.find_all(class_ = 'news_tit')

for i in title:
    print(i.text, " : ", i.attrs['href'])
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려"  :  http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료  :  http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부  :  https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?  :  https://view.asiae.co.kr/article/2022102614482734312
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  https://www.yna.co.kr/view/AKR20221027058900009?input=1195m
# '지구안보'의 눈으로 본 우크라이나전쟁  :  https://www.pressian.com/pages/articles/2022102616183903030?utm_source=naver&utm_medium=search
# 악수하는 독일-우크라이나 대통령  :  http://www.newsis.com/view/?id=NISI20221026_0001114670
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나  :  https://www.khan.co.kr/world/europe-russia/article/202210261512001
# ...

# %% [markdown]
# ## 여러 페이지 불러오기

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98&nso=so%3Ar%2Cp%3Aall%2Ca%3Aall'
url2 = '&start='

for i in range(1, 22, 10):
    url = url1 + url2 + str(i)
    html = requests.get(url, headers = header).text
    
    soup = BeautifulSoup(html, 'lxml')
    title = soup.find_all(class_ = 'news_tit')
    for j in title:
        print(j.text, " : ", j.attrs['href'])
    print(f'{i}페이지입니다.')
    print("-"*100)
    print('\n')
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려"  :  http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료  :  http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부  :  https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?  :  https://view.asiae.co.kr/article/2022102614482734312
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  https://www.yna.co.kr/view/AKR20221027058900009?input=1195m
# '지구안보'의 눈으로 본 우크라이나전쟁  :  https://www.pressian.com/pages/articles/2022102616183903030?utm_source=naver&utm_medium=search
# 악수하는 독일-우크라이나 대통령  :  http://www.newsis.com/view/?id=NISI20221026_0001114670
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나  :  https://www.khan.co.kr/world/europe-russia/article/202210261512001
# ...

# %% [markdown]
# ## 검색어 바꾸기

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='
url2 = input("검색어를 입력해 주세요: ")
url3 = '&nso=so%3Ar%2Cp%3Aall%2Ca%3Aall&start='

for i in range(1, 22, 10):
    url = url1 + url2 + url3 + str(i)
    html = requests.get(url, headers = header).text
    
    soup = BeautifulSoup(html, 'lxml')
    title = soup.find_all(class_ = 'news_tit')
    for j in title:
        print(j.text, " : ", j.attrs['href'])
    print(f'{i}페이지입니다.')
    print("-"*100)
    print('\n')
# Out:
# 검색어를 입력해 주세요: 우크라이나
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려"  :  http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료  :  http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부  :  https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?  :  https://view.asiae.co.kr/article/2022102614482734312
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  https://www.yna.co.kr/view/AKR20221027058900009?input=1195m
# '지구안보'의 눈으로 본 우크라이나전쟁  :  https://www.pressian.com/pages/articles/2022102616183903030?utm_source=naver&utm_medium=search
# 악수하는 독일-우크라이나 대통령  :  http://www.newsis.com/view/?id=NISI20221026_0001114670
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나  :  https://www.khan.co.kr/world/europe-russia/article/202210261512001
# ...

# %% [markdown]
# ## 사용자 함수로 만들기

# %%
def search(naver):
    import requests
    from bs4 import BeautifulSoup

    header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

    url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='
    url3 = '&nso=so%3Ar%2Cp%3Aall%2Ca%3Aall&start='

    for i in range(1, 22, 10):
        url = url1 + naver + url3 + str(i)
        html = requests.get(url, headers = header).text

        soup = BeautifulSoup(html, 'lxml')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            print(j.text, " : ", j.attrs['href'])
        print(f'{i}페이지입니다.')
        print("-"*100)
        print('\n')

# %%
search('우크라이나')
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상  :  http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려"  :  http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료  :  http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부  :  https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?  :  https://view.asiae.co.kr/article/2022102614482734312
# 대만, 우크라이나 재건에 약 800억원 지원키로  :  https://www.yna.co.kr/view/AKR20221027058900009?input=1195m
# '지구안보'의 눈으로 본 우크라이나전쟁  :  https://www.pressian.com/pages/articles/2022102616183903030?utm_source=naver&utm_medium=search
# 악수하는 독일-우크라이나 대통령  :  http://www.newsis.com/view/?id=NISI20221026_0001114670
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나  :  https://www.khan.co.kr/world/europe-russia/article/202210261512001
# ...

# %% [markdown]
# ## 저장하기

# %%
import pandas as pd

def search(naver):
    import requests
    from bs4 import BeautifulSoup
    header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

    url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='
    url3 = '&nso=so%3Ar%2Cp%3Aall%2Ca%3Aall&start='

    li1 = []
    li2 = []
    for i in range(1, 32, 10):
        url = url1 + naver + url3 + str(i)
        html = requests.get(url, headers = header).text

        soup = BeautifulSoup(html, 'lxml')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            li1.append(j.text)
            li2.append(j.attrs['href'])
        #print(li1)
        #print(li2)
        data = pd.DataFrame({'제목':li1, '링크':li2})
        data.to_csv(f"{naver}.csv")
        return data 
    
    
        #    print(j.text, " : ", j.attrs['href'])
        #print(f'{i}페이지입니다.')
        #print("-"*100)
        #print('\n')

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# # 이미지 크롤링

# %%
#soup은 웹브라우저에서 가져올 때 코드를 자기 맘대로 바꿔서 출력해주기 때문에
# find할 때 _image _listImage로 찾을 수 없다.
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B9%80%EC%97%B0%EC%95%84'
res = requests.get(url, headers = header).content
soup = BeautifulSoup(res, 'lxml')

# %%
images = soup.find_all(class_ = "_image _listImage")
images
# Out:
# []

# %% [markdown]
# ## selenium으로 페이지 소스 가져오기

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
import selenium
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus

# %%
url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2 = quote_plus('벨리곰')
url = url1 + url2
url
# Out:
# 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EB%B2%A8%EB%A6%AC%EA%B3%B0'

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %%
#get으로 페이지 열 때 시간이 걸릴 수도 있기 때문에 
#소스 저장하는 다음 셀 실행되기 전에 시간 텀을 줘야한다.
driver.get(url)

# %%
html = driver.page_source

# %%
driver.close()

# %% [markdown]
# ## 검색 & 저장

# %%
soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = "_image _listImage")
images
# Out:
# [<img alt="부산 X the sky &amp;시그니엘 벨리곰나도 봤다" class="_image _listImage" data-org-height="340" data-org-width="340" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA5MjJfMjY1%2FMDAxNjYzODUwNTc4ODMz.Z4lMBfH8m_bMQRjUzbm_QAMcp5-gk80UhQYJgSSlLUIg.4ASmV8DU5dbDLArvP3iphZyQLnfLERiL-FTax62I3wsg.JPEG.nhd4529%2FIMG%25A3%25DF20220804%25A3%25DF213008%25A3%25DF708.jpg&amp;type=a340" style="height: 218px; opacity: 1;"/>,
#  <img alt="롯데가 만든 NFT, 벨리곰에 대한 모든 것" class="_image _listImage" data-org-height="307" data-org-width="340" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA3MjFfMjU2%2FMDAxNjU4Mzg4Njg5MTgz.2g2a30n2Kiw90STIyi8MGORfHxC3zdpR3lcXXBRFbEAg.JUGjRgBJTvct6pG_MFN4pk9DYwxkPNYqCkH_4gCfmtMg.JPEG.lia_and_ray%2FIMG_9772.JPG&amp;type=a340" style="height: 197px; opacity: 1;"/>,
# ...

# %%
for i in images:
    print(i['src'])
# Out:
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA5MjJfMjY1%2FMDAxNjYzODUwNTc4ODMz.Z4lMBfH8m_bMQRjUzbm_QAMcp5-gk80UhQYJgSSlLUIg.4ASmV8DU5dbDLArvP3iphZyQLnfLERiL-FTax62I3wsg.JPEG.nhd4529%2FIMG%25A3%25DF20220804%25A3%25DF213008%25A3%25DF708.jpg&type=a340
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA3MjFfMjU2%2FMDAxNjU4Mzg4Njg5MTgz.2g2a30n2Kiw90STIyi8MGORfHxC3zdpR3lcXXBRFbEAg.JUGjRgBJTvct6pG_MFN4pk9DYwxkPNYqCkH_4gCfmtMg.JPEG.lia_and_ray%2FIMG_9772.JPG&type=a340
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMjA3MjlfMTQw%2FMDAxNjU5MDc4ODkwNTc1.va6mgAhSGU6veG6SOnExX7A-Dw8pP6CY69-h92NC0dsg.woA3VkyVn77AgwEfPTcjB0PynBkcIoXsV9WDkXLHEw4g.JPEG.i_min_u%2Foutput_1523342211.jpg&type=a340
# ...

# %%
import os
os.mkdir("kim")

# %%
count = 0

for image in images:
    from urllib.request import urlopen
    
    with urlopen(image['src']) as f:
        with open(f"./kim/{count}.jpg", 'wb') as g:
            data = f.read()
            g.write(data)
            count += 1

# %% [markdown]
# ## urlretrieve으로 저장하기

# %%
count = 0

for image in images:
    from urllib.request import urlretrieve
    
    urlretrieve(image['src'], f"./kim/{count}.jpg")
    count += 1

# %% [markdown]
# ## 최종코드

# %%
import selenium
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

url1 = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2 = quote_plus('벨리곰')
url = url1 + url2

driver.get(url) 

time.sleep(2)
#driver.implicitly_wait(10)  #최대 10초, 데이터 다 받으면 넘어감

html = driver.page_source
driver.close()

soup = BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = "_image _listImage")


count = 0
for image in images:
    urlretrieve(image['src'], f"./kim/{count}.jpg")
    count += 1

# %% [markdown]
# # 대통령 이름 불러오기

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D'

# %%
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.52'}

# %%
html = requests.get(url, headers = header).text
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## select로 찾기

# %%
#soup.select('#mw-content-text > div.mw-parser-output > table:nth-child(6) > tbody > tr > td > b > a')
#soup.select('div.mw-parser-output > table:nth-child(6) > tbody > tr > td > b > a')
#soup.select('table:nth-child(6) > tbody > tr > td > b > a')
soup.select('tbody > tr > td > b > a')
soup.select('tr > td > b > a')
soup.select('td > b > a')

# %%
names = soup.select('td > b > a')
names
# Out:
# [<a href="/wiki/%EC%9D%B4%EC%8A%B9%EB%A7%8C" title="이승만">이승만</a>,
#  <a href="/wiki/%EC%9C%A4%EB%B3%B4%EC%84%A0" title="윤보선">윤보선</a>,
#  <a href="/wiki/%EB%B0%95%EC%A0%95%ED%9D%AC" title="박정희">박정희</a>,
#  <a href="/wiki/%EC%B5%9C%EA%B7%9C%ED%95%98" title="최규하">최규하</a>,
#  <a href="/wiki/%EC%A0%84%EB%91%90%ED%99%98" title="전두환">전두환</a>,
#  <a href="/wiki/%EB%85%B8%ED%83%9C%EC%9A%B0" title="노태우">노태우</a>,
#  <a href="/wiki/%EA%B9%80%EC%98%81%EC%82%BC" title="김영삼">김영삼</a>,
#  <a href="/wiki/%EA%B9%80%EB%8C%80%EC%A4%91" title="김대중">김대중</a>,
#  <a href="/wiki/%EB%85%B8%EB%AC%B4%ED%98%84" title="노무현">노무현</a>,
#  <a href="/wiki/%EC%9D%B4%EB%AA%85%EB%B0%95" title="이명박">이명박</a>,
#  <a href="/wiki/%EB%B0%95%EA%B7%BC%ED%98%9C" title="박근혜">박근혜</a>,
#  <a href="/wiki/%EB%AC%B8%EC%9E%AC%EC%9D%B8" title="문재인">문재인</a>,
#  <a href="/wiki/%EC%9C%A4%EC%84%9D%EC%97%B4" title="윤석열">윤석열</a>]

# %%
[name.attrs['title'] for name in names]
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %% [markdown]
# ## find의 class로 찾기

# %%
names = soup.find(class_ = 'wikitable').find_all('b')
names
# Out:
# [<b>1</b>,
#  <b><a href="/wiki/%EC%9D%B4%EC%8A%B9%EB%A7%8C" title="이승만">이승만</a></b>,
#  <b>2</b>,
#  <b>3</b>,
#  <b>4</b>,
#  <b><a href="/wiki/%EC%9C%A4%EB%B3%B4%EC%84%A0" title="윤보선">윤보선</a></b>,
#  <b>5</b>,
#  <b><a href="/wiki/%EB%B0%95%EC%A0%95%ED%9D%AC" title="박정희">박정희</a></b>,
#  <b>6</b>,
#  <b>7</b>,
#  <b>8</b>,
#  <b>9</b>,
#  <b>10</b>,
#  <b><a href="/wiki/%EC%B5%9C%EA%B7%9C%ED%95%98" title="최규하">최규하</a></b>,
#  <b>11</b>,
#  <b><a href="/wiki/%EC%A0%84%EB%91%90%ED%99%98" title="전두환">전두환</a></b>,
#  <b>12</b>,
#  <b>13</b>,
#  <b><a href="/wiki/%EB%85%B8%ED%83%9C%EC%9A%B0" title="노태우">노태우</a></b>,
#  <b>14</b>,
#  <b><a href="/wiki/%EA%B9%80%EC%98%81%EC%82%BC" title="김영삼">김영삼</a></b>,
#  <b>15</b>,
#  <b><a href="/wiki/%EA%B9%80%EB%8C%80%EC%A4%91" title="김대중">김대중</a></b>,
#  <b>16</b>,
#  <b><a href="/wiki/%EB%85%B8%EB%AC%B4%ED%98%84" title="노무현">노무현</a></b>,
#  <b>17</b>,
#  <b><a href="/wiki/%EC%9D%B4%EB%AA%85%EB%B0%95" title="이명박">이명박</a></b>,
#  <b>18</b>,
# ...

# %%
names = [i.find('a') for i in names]
names = list(filter(None, names))
[i.text for i in names]
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %% [markdown]
# # 로그인 후 검색

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %%
driver = webdriver.Chrome('chromedriver', options=options)

# %% [markdown]
# ## 네이버

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://nid.naver.com/nidlogin.login'
driver.get(url)

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
# class로 찾기
e = driver.find_elements(By.CLASS_NAME, 'input_text')
e[0].clear()
e[0].send_keys("gmlwls123aa")
e[1].clear()
e[1].send_keys("heejin1584")

# %%
e[0].send_keys(Keys.ENTER)

# %%
# id로 찾기
e = driver.find_element(By.ID, "id") 
e.clear() 
e.send_keys("gmlwls123aa")
e = driver.find_element(By.ID, "pw") 
e.clear()
e.send_keys("heejin1584")

e.send_keys(Keys.ENTER)

# %%
#검색
e = driver.find_element(By.ID, "query") 
e.clear()
e.send_keys("우크라이나")
e.send_keys(Keys.ENTER)

# %% [markdown]
# ## 다음

# %%
#url = 'https://accounts.kakao.com/login?continue=https%3A%2F%2Flogins.daum.net'
url = 'https://accounts.kakao.com/login?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net'
driver.get(url)

# %%
e = driver.find_element(By.ID, "input-loginKey") 
e.clear()
e.send_keys("01064588025")
e = driver.find_element(By.ID, "input-password") 
e.clear()
e.send_keys("19467311")

# %%
e.send_keys(Keys.ENTER)

# %%
e = driver.find_element(By.ID, "q") 
e.clear()
e.send_keys("한국")
e.send_keys(Keys.ENTER)

# %% [markdown]
# ## 구글
#
# 구글로그인( 막혀있음)

# %%
url = 'https://accounts.google.com/v3/signin/identifier?dsh=S-1224157877%3A1666924908811231&continue=https%3A%2F%2Fwww.google.co.kr%2F&ec=GAZAmgQ&hl=ko&passive=true&flowName=GlifWebSignIn&flowEntry=ServiceLogin&ifkv=AQDHYWpYQcr9fLgBAexqRy0RAPrhxXK3fHLAwJWlTxh9BSDVOK1lkDzOy0SRBhvznSKz25btWUqkuw'
driver.get(url)

# %%
e = driver.find_element(By.ID, "identifierId") 
e.clear()
e.send_keys("01064588025")
e.send_keys(Keys.ENTER)

# %% [markdown]
# # 네이버 주문목록 가져오기

# %%
driver = webdriver.Chrome('chromedriver', options=options)

# %%
url = 'https://order.pay.naver.com/home?tabMenu=SHOPPING'
driver.get(url)

# %%
e = driver.find_elements(By.CLASS_NAME, 'input_text')
e[0].clear()
e[0].send_keys("gmlwls123aa")
e[1].clear()
e[1].send_keys("heejin1584")

# %%
e = driver.find_elements(By.CLASS_NAME, "name") 
e
# Out:
# []

# %%
for i in range(0, len(e)):
    print(e[i].text)

# %% [markdown]
# # 한빛출판 로그인&마일리지 보기

# %%
import requests
from bs4 import BeautifulSoup

# %%
session = requests.session()

# %%
type(session)
# Out:
# requests.sessions.Session

# %% [markdown]
# ```
# A -> ㅁ -> B
# A:로그인하는 창
# B:로그인 된 창
# A와 B 사이에 안보이는 정보를 입력되는 창이 존재한다.
# A에 있는 정보를 ㅁ에 주는 것
# ```

# %%
url = 'https://www.hanbit.co.kr/member/login_proc.php' 
session.post(url, {'m_id':'h22zin', 'm_passwd':'hjkk825zzang@'})
# Out:
# <Response [200]>

# %%
resp = session.get('https://www.hanbit.co.kr/myhanbit/myhanbit.html')

# %%
resp.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
html = resp.text
soup = BeautifulSoup(html, 'lxml')
soup

# %%
soup.select_one('dl.mileage_section1 > dd > span').text
soup.select_one('dl.mileage_section1 > dd > span').string
soup.select_one('dl.mileage_section1 > dd > span').get_text()
# Out:
# '2,000'

# %%
#container > div > div.sm_mymileage > dl.mileage_section1 > dd > span : 마일리지
#container > div > div.sm_mymileage > dl.mileage_section2 > dd > span : 이코인
soup.select('dd > span')
# Out:
# [<span>2,000</span>, <span>0</span>]

# %%
mileage = soup.select('dd > span')[0].text
ecoin = soup.select('dd > span')[1].text

name1 = soup.select(' dt')[0].text
name2 = soup.select(' dt')[1].text

# %%
print(name1, ' : ', mileage)
print(name2, ' : ', ecoin)
# Out:
# 마일리지  :  2,000
# 한빛이코인  :  0

# %% [markdown]
# # 날씨정보.json 형식 가져오기

# %%
import requests
import json

# %%
apikey = "28ed8b8682f52838a0a86e00b8578fcd"
api = "http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={key}"

# %%
cities = ['Seoul,KR', 'New York,US']

k2c = lambda k: round(k -273.15, 1)

# %%
for city in cities:
    #api로 정보 받아오기
    url = api.format(city = city, key = apikey)
    req = requests.get(url)
    
    #결과를 json 형식으로 변환하기
    data = json.loads(req.text)
    #print(data)
    print()
    print("+ 도시 =", data["name"])
    print("| 날씨 =", data["weather"][0]["description"])
    print("| 최저 기온 =", k2c(data["main"]["temp_min"]))
    print("| 최고 기온 =", k2c(data["main"]["temp_max"]))
    print("| 습도 =", data["main"]["humidity"])
    print("| 기압 =", data["main"]["pressure"])
    print("| 풍향 =", data["wind"]["deg"])
    print("| 풍속 =", data["wind"]["speed"])
    print("")
# Out:
# + 도시 = Seoul
# | 날씨 = clear sky
# | 최저 기온 = 15.7
# | 최고 기온 = 20.7
# | 습도 = 42
# | 기압 = 1025
# | 풍향 = 260
# | 풍속 = 2.06
#
#
# + 도시 = New York
# | 날씨 = clear sky
# | 최저 기온 = 5.7
# | 최고 기온 = 11.2
# | 습도 = 60
# | 기압 = 1029
# | 풍향 = 360
# | 풍속 = 8.75

# %% [markdown]
# ```
# cmd창에서 실행하기
# : python.exe myfilename.py
#
# 매일 같은 시간에 실행하기
# :작업 스케줄러에 파일을 저장해놓기or파이썬 자체에서 해주는 라이브러리가 있음
# ```

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time 

driver = webdriver.Chrome('chromedriver.exe')

#로그인 하기
driver.get("https://www.instagram.com/accounts/login/" )

e = driver.find_elements(By.CLASS_NAME, '_aa48')

e[0].send_keys("아이디")
e[1].send_keys("비밀번호")

e[0].send_keys(Keys.ENTER)

#나중에 설정&알림 창 넘어가기
e = driver.find_element(By.CLASS_NAME, '_ac8f')
e.click()
time.sleep(2)
e = driver.find_element(By.CLASS_NAME, '_a9-z')
e.click()

##검색하기
_keyword = '스튜디오' 
driver.get('https://www.instagram.com/explore/tags/' + _keyword + '/')

insta_tag = []
count = 100

#스크롤 내리기
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')

#첫 번째 게시물 클릭하기
driver.find_element(By.CLASS_NAME, '_aagw').click()


for i in range(count):
    #게시물 내용
    data = driver.find_element(By.CLASS_NAME, '_a9zs').text
    #태그만 뽑아내기
    tags = re.findall("#[A-Za-z0-9가-힣]+", data)
    tags = ''.join(tags).replace("#"," ")
    tags_data = tags.split()
    for tag in tags_data:
        insta_tag.append(tag)
        
    #다음 게시물로 이동
    driver.find_element(By.CLASS_NAME, '_abl-').send_keys(Keys.RIGHT) 
    time.sleep(2)

insta_tag

# %%
##빈도수 그래프 확인
import pandas as pd

df = pd.DataFrame(insta_tag)                        
df.rename({0 : 'word'}, axis = 1, inplace = True)   
df['count'] = df.iloc[:,0].str.len()
top20 = df.groupby('word', as_index = False).agg('count').sort_values('count', ascending = False)[0:20]

import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'            
plt.rcParams.update({'figure.figsize' :  [8,6] })            

 
sns.barplot(data = top20, y = 'word', x = 'count')
plt.xticks(rotation = 30)        
plt.show()
